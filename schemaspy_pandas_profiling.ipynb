# %% [markdown]
# <a href="https://colab.research.google.com/github/wcj365/pandas_profiling/blob/master/schemaspy_pandas_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Integration of Schema Spy and Pandas Profiling
#
# Modify the web page created by SchemaSpy to include a line to the summary page generated by Pandas Profiling. This is a perfect knowledge base for understanding a relational database including its metadata and data.

# %%
with open("index.html", "rt") as f:
    old_lines = f.readlines()

first_column = '<td class="detail"><a href="tables/'
last_column = '<td class="comment detail"'
link = '<td class="detail"><a href="profile/{}.html">Pandas Profile</a></td>\n'

with open("index2.html", "wt") as f:

    for line in old_lines:
        f.write(line)

        if line.strip().startswith(text):
            start = line.find(text)
            end = line.find(".html")
            table_name =  line[start:end].split("/")[-1]

        if line.strip().startswith(last_column):
            f.write(" " * 40 + link.format(table_name))
